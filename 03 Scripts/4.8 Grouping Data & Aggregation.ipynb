# %% [markdown]
# # 4.8 Grouping Data & Aggregation
#
# ## Instacart Grocery Basket Analysis
#
# #### -Errol Hinkamp
#
# ##### Table of Contents
#
# 1. Import libraries
# 2. Import data
# 3. Find aggregated mean of order number
# 4. Create loyalty flag
# 5. Examine spending habits by loyalty category
# 6. Create spending flag
# 7. Create frequency flag
# 8. Export data

# %% [markdown]
# # 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Import data

# %%
# Import dataframe
path=r'C:\Users\Errol\Documents\Data Analyst Work\Achievement 4\Instacart Basket Analysis'
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_new_columns.pkl'))

# %%
# Quick visual check
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#      busiest_days busiest_period_of_day
# 0  Regularly busy        Average orders
# 1    Slowest days        Average orders
# 2    Slowest days           Most orders
# 3    Slowest days        Average orders
# 4    Slowest days           Most orders

# %%
# Shape check
ords_prods_merged.shape
# Out:
# (32399732, 16)

# %% [markdown]
# # 3. Find aggregated mean of order number

# %%
# Find mean of 'order_number' grouped by 'department_id'
ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.667853
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ##### All departments are represented, rather than just some. Numbers are different since we're looking at a complete dataset.

# %% [markdown]
# # 4. Create loyalty flag

# %%
# Find maximum orders for each customer
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Disable row-viewing limits
pd.options.display.max_rows = None

# %%
# Quick visual check
ords_prods_merged[['user_id', 'order_number', 'max_order']].head(100)
# Out:
#     user_id  order_number  max_order
# 0         1             1         10
# 1         1             2         10
# 2         1             3         10
# 3         1             4         10
# 4         1             5         10
# 5         1             6         10
# 6         1             7         10
# 7         1             8         10
# 8         1             9         10
# 9         1            10         10
# 10       15            15         22
# 11       15            17         22
# 12       15            18         22
# 13       15            21         22
# 14       15            22         22
# 15       19             2          9
# 16       19             5          9
# 17       19             7          9
# 18       21            10         33
# 19       31            10         20
# 20       31            17         20
# 21       43             6         11
# 22       43             9         11
# 23       52             1         27
# 24       52             2         27
# 25       52             3         27
# 26       52             5         27
# 27       52             7         27
# 28       52             9         27
# 29       52            10         27
# 30       52            11         27
# 31       52            12         27
# 32       52            15         27
# 33       52            17         27
# 34       52            18         27
# 35       52            19         27
# 36       52            21         27
# 37       67             1         24
# 38       67             2         24
# 39       67             3         24
# 40       67             4         24
# 41       67             5         24
# 42       67             6         24
# 43       67             8         24
# 44       67             9         24
# 45       67            10         24
# 46       67            11         24
# 47       67            12         24
# 48       67            13         24
# 49       67            14         24
# 50       67            16         24
# 51       67            18         24
# 52       67            19         24
# 53       67            21         24
# 54       67            22         24
# 55       67            23         24
# 56       81             3          7
# 57       81             5          7
# 58       82             1         19
# 59       82             3         19
# 60       82             4         19
# 61       82             6         19
# 62       82             9         19
# 63       82            10         19
# 64       82            15         19
# 65       82            18         19
# 66       82            19         19
# 67       98             3         14
# 68       98             7         14
# 69       98             9         14
# 70       98            11         14
# 71       98            12         14
# 72       98            13         14
# 73       98            14         14
# 74      109             3          6
# 75      120             1          3
# 76      120             3          3
# 77      185             2          6
# 78      195             1         58
# 79      195             8         58
# 80      195            19         58
# 81      195            22         58
# 82      195            25         58
# 83      195            31         58
# 84      195            34         58
# 85      195            37         58
# 86      195            40         58
# 87      195            47         58
# 88      195            52         58
# 89      195            57         58
# 90      222            17         70
# 91      222            38         70
# 92      290             9         51
# 93      290            28         51
# 94      331             6          8
# 95      360             1          3
# 96      377             3          3
# 97      387             2          8
# 98      420             4         22
# 99      420             5         22

# %%
# Additional visual check
ords_prods_merged.groupby(['user_id'])['order_number'].nunique().head(100)
# Out:
# user_id
# 1      10
# 2      14
# 3      12
# 4       5
# 5       4
# 6       3
# 7      20
# 8       3
# 9       3
# 10      5
# 11      7
# 12      5
# 13     12
# 14     13
# 15     22
# 16      6
# 17     40
# 18      6
# 19      9
# 20      4
# 21     33
# 22     15
# 23      4
# 24     18
# 25      3
# 26     12
# 27     81
# 28     24
# 29     18
# 30      8
# 31     20
# 32      5
# 33      3
# 34      5
# 35      9
# 36     37
# 37     23
# 38     12
# 39      7
# 40      9
# 41      5
# 42     16
# 43     11
# 44      3
# 45      4
# 46     19
# 47      5
# 48     10
# 49      8
# 50     67
# 51      3
# 52     27
# 53      3
# 54     77
# 55      7
# 56     12
# 57     14
# 58     15
# 59     10
# 60      8
# 61      4
# 62     10
# 63     39
# 64     10
# 65     14
# 66      6
# 67     24
# 68      6
# 69      5
# 70     13
# 71     23
# 72     12
# 73      7
# 74      5
# 75     23
# 76      9
# 77     12
# 78      6
# 79      7
# 80     12
# 81      7
# 82     19
# 83      6
# 84      8
# 85      7
# 86     17
# 87     27
# 88      7
# 89     20
# 90     71
# 91     15
# 92      5
# 93     14
# 94      9
# 95      8
# 96     16
# 97      5
# 98     14
# 99     18
# 100     5
# Name: order_number, dtype: int64

# %% [markdown]
# ##### Everything matches. The user_ids were not grouped together, so a visual check wasn't showing all the relevant data.

# %%
# Create loyalty flag
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Quick visual check
ords_prods_merged[['user_id', 'order_number', 'max_order', 'loyalty_flag']].head(100)
# Out:
#     user_id  order_number  max_order      loyalty_flag
# 0         1             1         10      New customer
# 1         1             2         10      New customer
# 2         1             3         10      New customer
# 3         1             4         10      New customer
# 4         1             5         10      New customer
# 5         1             6         10      New customer
# 6         1             7         10      New customer
# 7         1             8         10      New customer
# 8         1             9         10      New customer
# 9         1            10         10      New customer
# 10       15            15         22  Regular customer
# 11       15            17         22  Regular customer
# 12       15            18         22  Regular customer
# 13       15            21         22  Regular customer
# 14       15            22         22  Regular customer
# 15       19             2          9      New customer
# 16       19             5          9      New customer
# 17       19             7          9      New customer
# 18       21            10         33  Regular customer
# 19       31            10         20  Regular customer
# 20       31            17         20  Regular customer
# 21       43             6         11  Regular customer
# 22       43             9         11  Regular customer
# 23       52             1         27  Regular customer
# 24       52             2         27  Regular customer
# 25       52             3         27  Regular customer
# 26       52             5         27  Regular customer
# 27       52             7         27  Regular customer
# 28       52             9         27  Regular customer
# 29       52            10         27  Regular customer
# 30       52            11         27  Regular customer
# 31       52            12         27  Regular customer
# 32       52            15         27  Regular customer
# 33       52            17         27  Regular customer
# 34       52            18         27  Regular customer
# 35       52            19         27  Regular customer
# 36       52            21         27  Regular customer
# 37       67             1         24  Regular customer
# 38       67             2         24  Regular customer
# 39       67             3         24  Regular customer
# 40       67             4         24  Regular customer
# 41       67             5         24  Regular customer
# 42       67             6         24  Regular customer
# 43       67             8         24  Regular customer
# 44       67             9         24  Regular customer
# 45       67            10         24  Regular customer
# 46       67            11         24  Regular customer
# 47       67            12         24  Regular customer
# 48       67            13         24  Regular customer
# 49       67            14         24  Regular customer
# 50       67            16         24  Regular customer
# 51       67            18         24  Regular customer
# 52       67            19         24  Regular customer
# 53       67            21         24  Regular customer
# 54       67            22         24  Regular customer
# 55       67            23         24  Regular customer
# 56       81             3          7      New customer
# 57       81             5          7      New customer
# 58       82             1         19  Regular customer
# 59       82             3         19  Regular customer
# 60       82             4         19  Regular customer
# 61       82             6         19  Regular customer
# 62       82             9         19  Regular customer
# 63       82            10         19  Regular customer
# 64       82            15         19  Regular customer
# 65       82            18         19  Regular customer
# 66       82            19         19  Regular customer
# 67       98             3         14  Regular customer
# 68       98             7         14  Regular customer
# 69       98             9         14  Regular customer
# 70       98            11         14  Regular customer
# 71       98            12         14  Regular customer
# 72       98            13         14  Regular customer
# 73       98            14         14  Regular customer
# 74      109             3          6      New customer
# 75      120             1          3      New customer
# 76      120             3          3      New customer
# 77      185             2          6      New customer
# 78      195             1         58    Loyal customer
# 79      195             8         58    Loyal customer
# 80      195            19         58    Loyal customer
# 81      195            22         58    Loyal customer
# 82      195            25         58    Loyal customer
# 83      195            31         58    Loyal customer
# 84      195            34         58    Loyal customer
# 85      195            37         58    Loyal customer
# 86      195            40         58    Loyal customer
# 87      195            47         58    Loyal customer
# 88      195            52         58    Loyal customer
# 89      195            57         58    Loyal customer
# 90      222            17         70    Loyal customer
# 91      222            38         70    Loyal customer
# 92      290             9         51    Loyal customer
# 93      290            28         51    Loyal customer
# 94      331             6          8      New customer
# 95      360             1          3      New customer
# 96      377             3          3      New customer
# 97      387             2          8      New customer
# 98      420             4         22  Regular customer
# 99      420             5         22  Regular customer

# %% [markdown]
# # 5. Examine spending habits by loyalty category

# %%
# Find min, max, mean price of items sorted by loyalty category
ords_prods_merged.groupby('loyalty_flag').agg({'prices':['min','max','mean']})
# Out:
#                  prices
#                     min   max      mean
# loyalty_flag
# Loyal customer      1.0  25.0  7.773575
# New customer        1.0  25.0  7.801206
# Regular customer    1.0  25.0  7.798262

# %% [markdown]
# # 6. Create spending flag

# %%
# Find average amount spent for each customer
ords_prods_merged['avg_spent'] = ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Quick visual check
ords_prods_merged[['user_id', 'prices', 'avg_spent']].head(100)
# Out:
#     user_id  prices  avg_spent
# 0         1     9.0   6.367797
# 1         1     9.0   6.367797
# 2         1     9.0   6.367797
# 3         1     9.0   6.367797
# 4         1     9.0   6.367797
# 5         1     9.0   6.367797
# 6         1     9.0   6.367797
# 7         1     9.0   6.367797
# 8         1     9.0   6.367797
# 9         1     9.0   6.367797
# 10       15     9.0   3.980556
# 11       15     9.0   3.980556
# 12       15     9.0   3.980556
# 13       15     9.0   3.980556
# 14       15     9.0   3.980556
# 15       19     9.0   8.372059
# 16       19     9.0   8.372059
# 17       19     9.0   8.372059
# 18       21     9.0   7.012683
# 19       31     9.0   8.137793
# 20       31     9.0   8.137793
# 21       43     9.0   7.444898
# 22       43     9.0   7.444898
# 23       52     9.0   6.356287
# 24       52     9.0   6.356287
# 25       52     9.0   6.356287
# 26       52     9.0   6.356287
# 27       52     9.0   6.356287
# 28       52     9.0   6.356287
# 29       52     9.0   6.356287
# 30       52     9.0   6.356287
# 31       52     9.0   6.356287
# 32       52     9.0   6.356287
# 33       52     9.0   6.356287
# 34       52     9.0   6.356287
# 35       52     9.0   6.356287
# 36       52     9.0   6.356287
# 37       67     9.0   7.656790
# 38       67     9.0   7.656790
# 39       67     9.0   7.656790
# 40       67     9.0   7.656790
# 41       67     9.0   7.656790
# 42       67     9.0   7.656790
# 43       67     9.0   7.656790
# 44       67     9.0   7.656790
# 45       67     9.0   7.656790
# 46       67     9.0   7.656790
# 47       67     9.0   7.656790
# 48       67     9.0   7.656790
# 49       67     9.0   7.656790
# 50       67     9.0   7.656790
# 51       67     9.0   7.656790
# 52       67     9.0   7.656790
# 53       67     9.0   7.656790
# 54       67     9.0   7.656790
# 55       67     9.0   7.656790
# 56       81     9.0   8.165385
# 57       81     9.0   8.165385
# 58       82     9.0   6.441221
# 59       82     9.0   6.441221
# 60       82     9.0   6.441221
# 61       82     9.0   6.441221
# 62       82     9.0   6.441221
# 63       82     9.0   6.441221
# 64       82     9.0   6.441221
# 65       82     9.0   6.441221
# 66       82     9.0   6.441221
# 67       98     9.0   8.028000
# 68       98     9.0   8.028000
# 69       98     9.0   8.028000
# 70       98     9.0   8.028000
# 71       98     9.0   8.028000
# 72       98     9.0   8.028000
# 73       98     9.0   8.028000
# 74      109     9.0   5.850725
# 75      120     9.0   9.385714
# 76      120     9.0   9.385714
# 77      185     9.0   7.715000
# 78      195     9.0   7.149730
# 79      195     9.0   7.149730
# 80      195     9.0   7.149730
# 81      195     9.0   7.149730
# 82      195     9.0   7.149730
# 83      195     9.0   7.149730
# 84      195     9.0   7.149730
# 85      195     9.0   7.149730
# 86      195     9.0   7.149730
# 87      195     9.0   7.149730
# 88      195     9.0   7.149730
# 89      195     9.0   7.149730
# 90      222     9.0   6.862397
# 91      222     9.0   6.862397
# 92      290     9.0   7.285597
# 93      290     9.0   7.285597
# 94      331     9.0   7.705128
# 95      360     9.0  10.006250
# 96      377     9.0   8.496552
# 97      387     9.0   7.396610
# 98      420     9.0   7.387805
# 99      420     9.0   7.387805

# %%
# Add spending flag
ords_prods_merged.loc[ords_prods_merged['avg_spent'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merged.loc[ords_prods_merged['avg_spent'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Quick visual check
ords_prods_merged[['user_id', 'avg_spent', 'spending_flag']].head(100)
# Out:
#     user_id  avg_spent spending_flag
# 0         1   6.367797   Low spender
# 1         1   6.367797   Low spender
# 2         1   6.367797   Low spender
# 3         1   6.367797   Low spender
# 4         1   6.367797   Low spender
# 5         1   6.367797   Low spender
# 6         1   6.367797   Low spender
# 7         1   6.367797   Low spender
# 8         1   6.367797   Low spender
# 9         1   6.367797   Low spender
# 10       15   3.980556   Low spender
# 11       15   3.980556   Low spender
# 12       15   3.980556   Low spender
# 13       15   3.980556   Low spender
# 14       15   3.980556   Low spender
# 15       19   8.372059   Low spender
# 16       19   8.372059   Low spender
# 17       19   8.372059   Low spender
# 18       21   7.012683   Low spender
# 19       31   8.137793   Low spender
# 20       31   8.137793   Low spender
# 21       43   7.444898   Low spender
# 22       43   7.444898   Low spender
# 23       52   6.356287   Low spender
# 24       52   6.356287   Low spender
# 25       52   6.356287   Low spender
# 26       52   6.356287   Low spender
# 27       52   6.356287   Low spender
# 28       52   6.356287   Low spender
# 29       52   6.356287   Low spender
# 30       52   6.356287   Low spender
# 31       52   6.356287   Low spender
# 32       52   6.356287   Low spender
# 33       52   6.356287   Low spender
# 34       52   6.356287   Low spender
# 35       52   6.356287   Low spender
# 36       52   6.356287   Low spender
# 37       67   7.656790   Low spender
# 38       67   7.656790   Low spender
# 39       67   7.656790   Low spender
# 40       67   7.656790   Low spender
# 41       67   7.656790   Low spender
# 42       67   7.656790   Low spender
# 43       67   7.656790   Low spender
# 44       67   7.656790   Low spender
# 45       67   7.656790   Low spender
# 46       67   7.656790   Low spender
# 47       67   7.656790   Low spender
# 48       67   7.656790   Low spender
# 49       67   7.656790   Low spender
# 50       67   7.656790   Low spender
# 51       67   7.656790   Low spender
# 52       67   7.656790   Low spender
# 53       67   7.656790   Low spender
# 54       67   7.656790   Low spender
# 55       67   7.656790   Low spender
# 56       81   8.165385   Low spender
# 57       81   8.165385   Low spender
# 58       82   6.441221   Low spender
# 59       82   6.441221   Low spender
# 60       82   6.441221   Low spender
# 61       82   6.441221   Low spender
# 62       82   6.441221   Low spender
# 63       82   6.441221   Low spender
# 64       82   6.441221   Low spender
# 65       82   6.441221   Low spender
# 66       82   6.441221   Low spender
# 67       98   8.028000   Low spender
# 68       98   8.028000   Low spender
# 69       98   8.028000   Low spender
# 70       98   8.028000   Low spender
# 71       98   8.028000   Low spender
# 72       98   8.028000   Low spender
# 73       98   8.028000   Low spender
# 74      109   5.850725   Low spender
# 75      120   9.385714   Low spender
# 76      120   9.385714   Low spender
# 77      185   7.715000   Low spender
# 78      195   7.149730   Low spender
# 79      195   7.149730   Low spender
# 80      195   7.149730   Low spender
# 81      195   7.149730   Low spender
# 82      195   7.149730   Low spender
# 83      195   7.149730   Low spender
# 84      195   7.149730   Low spender
# 85      195   7.149730   Low spender
# 86      195   7.149730   Low spender
# 87      195   7.149730   Low spender
# 88      195   7.149730   Low spender
# 89      195   7.149730   Low spender
# 90      222   6.862397   Low spender
# 91      222   6.862397   Low spender
# 92      290   7.285597   Low spender
# 93      290   7.285597   Low spender
# 94      331   7.705128   Low spender
# 95      360  10.006250  High spender
# 96      377   8.496552   Low spender
# 97      387   7.396610   Low spender
# 98      420   7.387805   Low spender
# 99      420   7.387805   Low spender

# %% [markdown]
# # 7. Create frequency flag

# %%
# Find median days since last order for each customer
ords_prods_merged['order_frequency'] = ords_prods_merged.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
# Quick visual check
ords_prods_merged[['user_id', 'days_since_last_order', 'order_frequency']].head(100)
# Out:
#     user_id  days_since_last_order  order_frequency
# 0         1                    NaN             20.5
# 1         1                   15.0             20.5
# 2         1                   21.0             20.5
# 3         1                   29.0             20.5
# 4         1                   28.0             20.5
# 5         1                   19.0             20.5
# 6         1                   20.0             20.5
# 7         1                   14.0             20.5
# 8         1                    0.0             20.5
# 9         1                   30.0             20.5
# 10       15                    7.0             10.0
# 11       15                    8.0             10.0
# 12       15                    7.0             10.0
# 13       15                    7.0             10.0
# 14       15                   14.0             10.0
# 15       19                    6.0              6.0
# 16       19                    8.0              6.0
# 17       19                    6.0              6.0
# 18       21                    6.0              7.5
# 19       31                    7.0              6.0
# 20       31                    8.0              6.0
# 21       43                    4.0             10.0
# 22       43                    3.0             10.0
# 23       52                    NaN              8.0
# 24       52                    7.0              8.0
# 25       52                    7.0              8.0
# 26       52                    8.0              8.0
# 27       52                    8.0              8.0
# 28       52                    7.0              8.0
# 29       52                    8.0              8.0
# 30       52                    7.0              8.0
# 31       52                    6.0              8.0
# 32       52                    8.0              8.0
# 33       52                    6.0              8.0
# 34       52                   14.0              8.0
# 35       52                    8.0              8.0
# 36       52                   30.0              8.0
# 37       67                    NaN              7.0
# 38       67                    5.0              7.0
# 39       67                    7.0              7.0
# 40       67                    8.0              7.0
# 41       67                    8.0              7.0
# 42       67                    7.0              7.0
# 43       67                    7.0              7.0
# 44       67                    7.0              7.0
# 45       67                    6.0              7.0
# 46       67                    7.0              7.0
# 47       67                    8.0              7.0
# 48       67                    6.0              7.0
# 49       67                    7.0              7.0
# 50       67                    9.0              7.0
# 51       67                    4.0              7.0
# 52       67                    9.0              7.0
# 53       67                    5.0              7.0
# 54       67                   14.0              7.0
# 55       67                   14.0              7.0
# 56       81                   14.0             30.0
# 57       81                   30.0             30.0
# 58       82                    NaN             11.5
# 59       82                    5.0             11.5
# 60       82                   16.0             11.5
# 61       82                   13.0             11.5
# 62       82                   30.0             11.5
# 63       82                    1.0             11.5
# 64       82                   12.0             11.5
# 65       82                    7.0             11.5
# 66       82                    8.0             11.5
# 67       98                   25.0             25.0
# 68       98                    5.0             25.0
# 69       98                   30.0             25.0
# 70       98                   15.0             25.0
# 71       98                   30.0             25.0
# 72       98                   30.0             25.0
# 73       98                    8.0             25.0
# 74      109                    9.0             26.0
# 75      120                    NaN             19.0
# 76      120                   19.0             19.0
# 77      185                   25.0             25.0
# 78      195                    NaN              4.0
# 79      195                    4.0              4.0
# 80      195                    3.0              4.0
# 81      195                    7.0              4.0
# 82      195                    4.0              4.0
# 83      195                    4.0              4.0
# 84      195                    6.0              4.0
# 85      195                    0.0              4.0
# 86      195                    2.0              4.0
# 87      195                    2.0              4.0
# 88      195                    2.0              4.0
# 89      195                    3.0              4.0
# 90      222                    1.0              5.0
# 91      222                    1.0              5.0
# 92      290                    6.0              7.0
# 93      290                    7.0              7.0
# 94      331                   30.0             30.0
# 95      360                    NaN              4.0
# 96      377                    3.0             16.5
# 97      387                   22.0              8.0
# 98      420                   30.0              7.0
# 99      420                   16.0              7.0

# %%
# Add frequency flag
ords_prods_merged.loc[ords_prods_merged['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merged.loc[(ords_prods_merged['order_frequency'] <= 20) & (ords_prods_merged['order_frequency'] > 10), 'frequency_flag'] = 'Regular customer'
ords_prods_merged.loc[ords_prods_merged['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Quick visual check
ords_prods_merged[['user_id', 'order_frequency', 'frequency_flag']].head(100)
# Out:
#     user_id  order_frequency         frequency_flag
# 0         1             20.5  Non-frequent customer
# 1         1             20.5  Non-frequent customer
# 2         1             20.5  Non-frequent customer
# 3         1             20.5  Non-frequent customer
# 4         1             20.5  Non-frequent customer
# 5         1             20.5  Non-frequent customer
# 6         1             20.5  Non-frequent customer
# 7         1             20.5  Non-frequent customer
# 8         1             20.5  Non-frequent customer
# 9         1             20.5  Non-frequent customer
# 10       15             10.0      Frequent customer
# 11       15             10.0      Frequent customer
# 12       15             10.0      Frequent customer
# 13       15             10.0      Frequent customer
# 14       15             10.0      Frequent customer
# 15       19              6.0      Frequent customer
# 16       19              6.0      Frequent customer
# 17       19              6.0      Frequent customer
# 18       21              7.5      Frequent customer
# 19       31              6.0      Frequent customer
# 20       31              6.0      Frequent customer
# 21       43             10.0      Frequent customer
# 22       43             10.0      Frequent customer
# 23       52              8.0      Frequent customer
# 24       52              8.0      Frequent customer
# 25       52              8.0      Frequent customer
# 26       52              8.0      Frequent customer
# 27       52              8.0      Frequent customer
# 28       52              8.0      Frequent customer
# 29       52              8.0      Frequent customer
# 30       52              8.0      Frequent customer
# 31       52              8.0      Frequent customer
# 32       52              8.0      Frequent customer
# 33       52              8.0      Frequent customer
# 34       52              8.0      Frequent customer
# 35       52              8.0      Frequent customer
# 36       52              8.0      Frequent customer
# 37       67              7.0      Frequent customer
# 38       67              7.0      Frequent customer
# 39       67              7.0      Frequent customer
# 40       67              7.0      Frequent customer
# 41       67              7.0      Frequent customer
# 42       67              7.0      Frequent customer
# 43       67              7.0      Frequent customer
# 44       67              7.0      Frequent customer
# 45       67              7.0      Frequent customer
# 46       67              7.0      Frequent customer
# 47       67              7.0      Frequent customer
# 48       67              7.0      Frequent customer
# 49       67              7.0      Frequent customer
# 50       67              7.0      Frequent customer
# 51       67              7.0      Frequent customer
# 52       67              7.0      Frequent customer
# 53       67              7.0      Frequent customer
# 54       67              7.0      Frequent customer
# 55       67              7.0      Frequent customer
# 56       81             30.0  Non-frequent customer
# 57       81             30.0  Non-frequent customer
# 58       82             11.5       Regular customer
# 59       82             11.5       Regular customer
# 60       82             11.5       Regular customer
# 61       82             11.5       Regular customer
# 62       82             11.5       Regular customer
# 63       82             11.5       Regular customer
# 64       82             11.5       Regular customer
# 65       82             11.5       Regular customer
# 66       82             11.5       Regular customer
# 67       98             25.0  Non-frequent customer
# 68       98             25.0  Non-frequent customer
# 69       98             25.0  Non-frequent customer
# 70       98             25.0  Non-frequent customer
# 71       98             25.0  Non-frequent customer
# 72       98             25.0  Non-frequent customer
# 73       98             25.0  Non-frequent customer
# 74      109             26.0  Non-frequent customer
# 75      120             19.0       Regular customer
# 76      120             19.0       Regular customer
# 77      185             25.0  Non-frequent customer
# 78      195              4.0      Frequent customer
# 79      195              4.0      Frequent customer
# 80      195              4.0      Frequent customer
# 81      195              4.0      Frequent customer
# 82      195              4.0      Frequent customer
# 83      195              4.0      Frequent customer
# 84      195              4.0      Frequent customer
# 85      195              4.0      Frequent customer
# 86      195              4.0      Frequent customer
# 87      195              4.0      Frequent customer
# 88      195              4.0      Frequent customer
# 89      195              4.0      Frequent customer
# 90      222              5.0      Frequent customer
# 91      222              5.0      Frequent customer
# 92      290              7.0      Frequent customer
# 93      290              7.0      Frequent customer
# 94      331             30.0  Non-frequent customer
# 95      360              4.0      Frequent customer
# 96      377             16.5       Regular customer
# 97      387              8.0      Frequent customer
# 98      420              7.0      Frequent customer
# 99      420              7.0      Frequent customer

# %% [markdown]
# # 8. Export data

# %%
# Export dataframe
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4.8.pkl'))
