# %% [markdown]
# # 4.7 Deriving New Variables
#
# ## Instacart Grocery Basket Analysis
#
# #### -Errol Hinkamp
#
# ##### Table of Contents
#
# 1. Import libraries
# 2. Import data
# 3. Exercise walkthrough
# - 3.1 Trim dataframe
# - 3.2 Create new function
# - 3.3 Create new function with loc()
# - 3.4 Use loc() function on whole dataframe
# - 3.5 Use if-statement with for-loop
# 4. Create busiest days column
# 5. Create busiest hours column
# 6. Export data

# %% [markdown]
# # 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Import data

# %%
# Import dataframe
path=r'C:\Users\Errol\Documents\Data Analyst Work\Achievement 4\Instacart Basket Analysis'
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Quick visual check of merged dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices
# 0         Soda        77              7     9.0
# ...

# %%
# Check shape of merged dataframe
df_ords_prods_merged.shape
# Out:
# (32399732, 13)

# %% [markdown]
# ##### Matches size of exported data from previous exercise

# %% [markdown]
# # 3. Exercise walkthrough

# %% [markdown]
# ### 3.1 Trim dataframe

# %%
# Make dataframe consisting of only the first million rows
df = df_ords_prods_merged[:1000000]

# %%
# Quick visual check of new dataframe
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices
# 0         Soda        77              7     9.0
# ...

# %%
# Check shape of new dataframe
df.shape
# Out:
# (1000000, 13)

# %% [markdown]
# ### 3.2 Create new function

# %%
# Define new function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-9-b47ea848c9b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Tally up price ranges
df['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Check most expensive item in dataset
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ### 3.3 Create new function with loc()

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Errol\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Errol\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\Errol\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\Errol\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### 3.4 Use loc() function on whole dataframe

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      412551
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### 3.5 Use if-statement with for-loop

# %%
# Determine busiest day of week
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6203329
# 1    5659298
# 6    4495887
# 2    4213105
# 5    4205076
# 3    3839865
# 4    3783172
# Name: orders_day_of_week, dtype: int64

# %%
# Create column for busy-ness
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add column to dataframe
df_ords_prods_merged['busiest_day']=result

# %%
# Double-check that values of new column are consistent with above
df_ords_prods_merged['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22413231
# Busiest day        6203329
# Least busy         3783172
# Name: busiest_day, dtype: int64

# %%
# Quick visual check of dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# # 4. Create busiest days column

# %%
# Create column for busy-ness
result1 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result1.append("Busiest days")
  elif value == 1:
    result1.append("Busiest days")
  elif value == 3:
    result1.append("Slowest days")
  elif value == 4:
    result1.append("Slowest days")
  else:
    result1.append("Regularly busy")

# %%
result1
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# Add column to dataframe
df_ords_prods_merged['busiest_days']=result1

# %%
# Remove old 'busiest_day' column
df_ords_prods_merged=df_ords_prods_merged.drop(columns = ['busiest_day'])

# %%
# Double-check that values of new column are consistent with previous checks
df_ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy    12914068
# Busiest days      11862627
# Slowest days       7623037
# Name: busiest_days, dtype: int64

# %%
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6203329
# 1    5659298
# 6    4495887
# 2    4213105
# 5    4205076
# 3    3839865
# 4    3783172
# Name: orders_day_of_week, dtype: int64

# %%
# Two busiest days
6203329+5659298
# Out:
# 11862627

# %%
# Two least busy days
3839865+3783172
# Out:
# 7623037

# %%
# Remaining days
4495887+4213105+4205076
# Out:
# 12914068

# %% [markdown]
# ##### All numbers match up

# %% [markdown]
# # 5. Create busiest hours column

# %%
# Determine busiest hours
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761333
# 11    2735694
# 14    2688728
# 15    2661718
# 13    2660570
# 12    2618104
# 16    2534744
# 9     2453842
# 17    2087273
# 8     1717863
# 18    1636226
# 19    1258076
# 20     976000
# 7      890923
# 21     795528
# 22     634159
# 23     402272
# 6      290450
# 0      218742
# 1      115683
# 5       87944
# 2       69360
# 4       53232
# 3       51268
# Name: order_hour_of_day, dtype: int64

# %%
# Create new column for busy hours
result2 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value == 10:
    result2.append("Most orders")
  elif value == 11:
    result2.append("Most orders")
  elif value == 14:
    result2.append("Most orders")
  elif value == 15:
    result2.append("Most orders")
  elif value == 13:
    result2.append("Most orders")
  elif value == 12:
    result2.append("Most orders")
  elif value == 16:
    result2.append("Most orders")
  elif value == 9:
    result2.append("Most orders")
  elif value == 3:
    result2.append("Fewest orders")
  elif value == 4:
    result2.append("Fewest orders")
  elif value == 2:
    result2.append("Fewest orders")
  elif value == 5:
    result2.append("Fewest orders")
  elif value == 1:
    result2.append("Fewest orders")  
  elif value == 0:
    result2.append("Fewest orders")
  elif value == 6:
    result2.append("Fewest orders")
  elif value == 23:
    result2.append("Fewest orders")
  else:
    result2.append("Average orders")

# %%
result2
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Add column to dataframe
df_ords_prods_merged['busiest_period_of_day']=result2

# %%
# Quick visual check of dataframe
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# ...

# %%
# Print frequency of new column
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Most orders       21114733
# Average orders     9996048
# Fewest orders      1288951
# Name: busiest_period_of_day, dtype: int64

# %%
# Determine busiest hours
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761333
# 11    2735694
# 14    2688728
# 15    2661718
# 13    2660570
# 12    2618104
# 16    2534744
# 9     2453842
# 17    2087273
# 8     1717863
# 18    1636226
# 19    1258076
# 20     976000
# 7      890923
# 21     795528
# 22     634159
# 23     402272
# 6      290450
# 0      218742
# 1      115683
# 5       87944
# 2       69360
# 4       53232
# 3       51268
# Name: order_hour_of_day, dtype: int64

# %%
# Most orders
2761333+2735694+2688728+2661718+2660570+2618104+2534744+2453842
# Out:
# 21114733

# %%
# Fewest orders
51268+53232+69360+87944+115683+218742+290450+402272
# Out:
# 1288951

# %%
# Average orders
2087273+1717863+1636226+1258076+976000+890923+795528+634159
# Out:
# 9996048

# %% [markdown]
# ##### All numbers add up correctly

# %% [markdown]
# # 6. Export data

# %%
# Export dataframe
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_new_columns.pkl'))
